# %%
from google import genai
import os
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

resp = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Hello detective, testing the murder mystery engine."
)

print(resp.text)
# Out:
# Alright, I'm ready. Hit me with the details. Let's see if we can crack this case. Give me everything you've got:
#
# *   **Who is the victim?**
# *   **What is the location of the murder?**
# *   **What is the time of the murder?**
# *   **What are the circumstances surrounding the murder?**
# *   **Do we have any potential suspects?**
#
# The more information you provide, the better I can investigate! Let's get started.
